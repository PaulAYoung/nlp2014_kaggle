# %%
import re
import random
from os import path

import nltk

import testing_util as util
import term_scoring
from testing_util import sample_sets, final_sets

# %%
from nltk.classify import SklearnClassifier
from sklearn.svm import SVC

# %%
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.stem.PorterStemmer()

def get_terms(t):
    """
    This is used to get the relevant items out of text. 
    """
    tokens = nltk.word_tokenize(t)
    return [stemmer.stem(w.lower()) for w in tokens if len(w)>3 and (w not in stopwords)]

# %%
def category_term_scorer(sample_list):
    """
    takes a list of tuples in format (category,text) and creates scores for each term
    for its relevance to each category
    """
    categories = {}
    
    for c,s in sample_list:
        if c not in categories:
            categories[c]=[]
        for w in get_terms(s):
            categories[c].append(w)
    
    fd_all = nltk.FreqDist([w for wl in categories.values() for w in wl])
    
    fd_categories = {c:nltk.FreqDist(v) for c,v in categories.iteritems()}
    
    term_scores = {}
    for term in fd_all.iterkeys():
        if fd_all[term] < 3:
            continue
        d = {}
        for c,fd in fd_categories.iteritems():
            d[c]= fd[term]/(1+fd_all[term]-fd[term])
        term_scores[term]=d
    
    return term_scores

# %%
feature_term_score = term_scoring.TermScoreBagger(scorer=category_term_scorer)

# %%
def feature_num_tokens(text):
    return {"num_tokens": len(nltk.word_tokenize(text))/10}

# %%
def feature_avg_len_word(text):
    tokens = nltk.word_tokenize(text)
    return {"word_len": sum([len(w) for w in tokens])/len(tokens)}

# %%
extractor = util.FeatureExtractor()
#extractor.add_extractor(feature_num_tokens)
#extractor.add_extractor(feature_avg_len_word)
extractor.add_extractor(feature_term_score, trained=True)

# %%
extractor.test(sample_sets, folds=3,confusion=True, classifier=SklearnClassifier(SVC(), sparse=False), num_tests=1)
# Out:
# **************************
# Run 0
# **************************
# test 0 - 46.274%
#   |      1      2      3      4      6      7      5 |
# --+--------------------------------------------------+
# 1 | <20.4%>  3.1%   1.1%   2.2%   0.2%   0.1%   0.8% |
# 2 |   6.5% <10.5%>  0.4%   0.3%   0.1%   0.1%   0.3% |
# 3 |   8.1%   1.0%  <4.4%>  1.3%      .   0.1%      . |
# 4 |   5.3%   0.1%      .  <7.2%>  0.2%   0.1%      . |
# 6 |   5.6%   0.4%   0.2%   0.7%  <2.2%>     .   0.1% |
# 7 |   6.5%   0.3%   0.2%   0.1%   0.2%  <1.0%>  0.2% |
# 5 |   6.0%   0.6%   0.1%   0.3%   0.3%   0.1%  <0.6%>|
# --+--------------------------------------------------+
# (row = reference; col = test)
# test 1 - 44.828%
#   |      1      2      4      3      5      7      6 |
# --+--------------------------------------------------+
# 1 | <20.1%>  4.2%   2.1%   1.0%   0.2%   1.0%   1.0% |
# 2 |   4.4%  <9.7%>     .   1.0%   0.1%   0.3%      . |
# 4 |   5.5%   0.4%  <7.3%>  0.4%      .      .   0.2% |
# 3 |   6.6%   0.8%   1.1%  <4.6%>     .   0.1%      . |
# 5 |   7.8%   0.8%   0.4%   1.0%  <0.1%>  0.1%   0.3% |
# 7 |   6.3%   0.2%      .   0.4%   0.2%  <1.2%>  0.6% |
# 6 |   5.3%   0.2%   0.7%   0.1%      .      .  <1.8%>|
# --+--------------------------------------------------+
# (row = reference; col = test)
# test 2 - 44.778%
#   |      1      3      2      4      7      5      6 |
# --+--------------------------------------------------+
# 1 | <19.1%>  0.7%   3.9%   3.0%   0.3%   0.4%   0.4% |
# 3 |   9.2%  <5.0%>  1.0%   1.0%   0.1%   0.4%   0.2% |
# 2 |   5.6%   0.2% <10.4%>  0.2%   0.1%      .   0.1% |
# 4 |   3.6%   0.3%   0.6%  <6.9%>     .      .   0.3% |
# 7 |   7.6%   0.2%   0.9%      .  <0.7%>  0.3%   0.1% |
# 5 |   5.3%   0.4%   0.8%   0.1%   0.3%  <1.1%>  0.4% |
# 6 |   5.7%   0.1%   0.3%   0.7%      .   0.1%  <1.6%>|
# --+--------------------------------------------------+
# (row = reference; col = test)

# %%
#extractor.test_extractors(sample_sets, classifier=SklearnClassifier(SVC(), sparse=False))

# %%
cl=extractor.get_classifier(sample_sets, classifier=SklearnClassifier(SVC(), sparse=False))

# %%
[type(i[0]) for i in sample_sets]
# Out:
# [str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  ...]

# %%
final_features = util.make_feature(extractor, final_sets)

# %%
submission = util.make_submission(cl, final_features, writeto="submission4.csv")
